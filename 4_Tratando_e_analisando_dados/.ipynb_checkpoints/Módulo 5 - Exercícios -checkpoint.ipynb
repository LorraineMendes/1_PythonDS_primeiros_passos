# %%
import pandas as pd

# %%
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %% [markdown]
# ## Crie um DataFrame somente com os alunos aprovados.

# %%
aprovados = alunos['Aprovado'] == True

# %%
aprovados
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6    False
# 7    False
# Name: Aprovado, dtype: bool

# %%
alunos[aprovados]
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 0    Ary     15    M    7.5      True
# 3   Beto     32    M   10.0      True
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %% [markdown]
# ## Crie um DataFrame somente com as alunas aprovadas.

# %%
alunas_aprovadas = (alunos['Aprovado'] == True) & (alunos['Sexo'] == 'F') 
alunas_aprovadas
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# dtype: bool

# %%
alunos[alunas_aprovadas]
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
alunas = (alunos.Aprovado == True) & (alunos.Sexo == 'F')
alunas
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# dtype: bool

# %%
alunos[alunas]
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %% [markdown]
# ## Crie apenas uma visualização dos alunos com idade entre 10 e 20 anos ou com idade maior ou igual a 40 anos.

# %%
idade_10_a_20_ou_mais_40 = ((alunos['Idade'] < 20) & (alunos['Idade'] > 10)) | (alunos['Idade'] >= 40)
idade_10_a_20_ou_mais_40
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# Name: Idade, dtype: bool

# %%
alunos[idade_10_a_20_ou_mais_40]
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 2   Denis     56    M    5.0     False
# 4   Bruna     42    F    8.2      True
# 6  Carlos     19    M    6.0     False

# %% [markdown]
# ## Crie um DataFrame somente com os alunos reprovados e mantenha neste DataFrame apenas as colunas Nome, Sexo e Idade, nesta ordem.

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
reprovados = alunos['Aprovado'] == False
alunos[reprovados]
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
alunos_reprovados = alunos[reprovados]

# %%
alunos_reprovados[['Nome', 'Sexo', 'Idade']]
# Out:
#      Nome Sexo  Idade
# 1   Cátia    F     27
# 2   Denis    M     56
# 6  Carlos    M     19
# 7   Alice    F     35

# %%
## Outra forma
reprovados_ = alunos.loc[reprovados,['Nome', 'Sexo', 'Idade']]
reprovados;

# %% [markdown]
# ## Crie uma visualização com os três alunos mais novos.

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
alunos.sort_values(by=['Idade'])
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 6  Carlos     19    M    6.0     False
# 5    Dara     21    F    7.0      True
# 1   Cátia     27    F    2.5     False
# 3    Beto     32    M   10.0      True
# 7   Alice     35    F    5.6     False
# 4   Bruna     42    F    8.2      True
# 2   Denis     56    M    5.0     False

# %%
ordem = alunos.sort_values(by=['Idade'])
ordem[:3]
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 6  Carlos     19    M    6.0     False
# 5    Dara     21    F    7.0      True

# %%
# Na correção esta assim:
alunos.sort_values(by=['Idade'], inplace = True)
alunos.iloc[:3]
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 6  Carlos     19    M    6.0     False
# 5    Dara     21    F    7.0      True
