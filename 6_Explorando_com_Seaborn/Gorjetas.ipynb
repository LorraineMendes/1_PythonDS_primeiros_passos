# %% [markdown]
# # Módulo 1 -  Importando e traduzindo os dados

# %% [markdown]
# ## Importando base de dados

# %%
import pandas as pd

# %%
pd.read_csv('tips.csv')
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
dados = pd.read_csv('tips.csv')

# %%
dados
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
dados.head(6)
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4
# 5       25.29  4.71      No  Sun  Dinner     4

# %% [markdown]
# ## Traduzindo colunas e campos

# %%
dados.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
renomear = {'total_bill': 'valor_da_conta',
            'tip':'gorjeta', 
            'dessert':'sobremesa',
            'day':'dia_da_semana', 
            'time':'hora_do_dia',
            'size': 'total_de_pessoas'}

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
gorjetas = dados.rename(columns = renomear)

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No           Sun      Dinner
# 1           10.34     1.66        No           Sun      Dinner
# 2           21.01     3.50        No           Sun      Dinner
# 3           23.68     3.31        No           Sun      Dinner
# 4           24.59     3.61        No           Sun      Dinner
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4

# %%
gorjetas.sobremesa.unique() #visualisando todos os tipos
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao ={'No': 'Não',
          'Yes':'Sim'
}

# %%
gorjetas.sobremesa.map(sim_nao)
# Out:
# 0      Não
# 1      Não
# 2      Não
# 3      Não
# 4      Não
#       ...
# 239    Não
# 240    Sim
# 241    Sim
# 242    Não
# 243    Não
# Name: sobremesa, Length: 244, dtype: object

# %%
#Atribuindo o novo nome

gorjetas.sobremesa = gorjetas.sobremesa.map(sim_nao)

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não           Sun      Dinner
# 1           10.34     1.66       Não           Sun      Dinner
# 2           21.01     3.50       Não           Sun      Dinner
# 3           23.68     3.31       Não           Sun      Dinner
# 4           24.59     3.61       Não           Sun      Dinner
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dias={
    'Sun':'Domingo', 
    'Sat':'Sábado', 
    'Thur':'Quinta', 
    'Fri':'Sexta'
}

# %%
gorjetas.dia_da_semana.map(dias)
# Out:
# 0      Domingo
# 1      Domingo
# 2      Domingo
# 3      Domingo
# 4      Domingo
#         ...
# 239     Sábado
# 240     Sábado
# 241     Sábado
# 242     Sábado
# 243     Quinta
# Name: dia_da_semana, Length: 244, dtype: object

# %%
gorjetas.dia_da_semana = gorjetas.dia_da_semana.map(dias)

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Dinner
# 1           10.34     1.66       Não       Domingo      Dinner
# 2           21.01     3.50       Não       Domingo      Dinner
# 3           23.68     3.31       Não       Domingo      Dinner
# 4           24.59     3.61       Não       Domingo      Dinner
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
hora = {
    'Dinner':'Jantar', 
    'Lunch':'Almoço'
}

# %%
gorjetas.hora_do_dia = gorjetas.hora_do_dia.map(hora)

# %%
gorjetas.head(200)
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Jantar
# 1             10.34     1.66       Não       Domingo      Jantar
# 2             21.01     3.50       Não       Domingo      Jantar
# 3             23.68     3.31       Não       Domingo      Jantar
# 4             24.59     3.61       Não       Domingo      Jantar
# ..              ...      ...       ...           ...         ...
# 195            7.56     1.44       Não        Quinta      Almoço
# 196           10.34     2.00       Sim        Quinta      Almoço
# 197           43.11     5.00       Sim        Quinta      Almoço
# 198           13.00     2.00       Sim        Quinta      Almoço
# 199           13.51     2.00       Sim        Quinta      Almoço
#
#      total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# ...

# %% [markdown]
# # Módulo 2 - Comparando distribuições de maneira exploratória

# %% [markdown]
# ## Seaborn e Scatterplot

# %%
# !pip install seaborn==0.9.0

# %%
import seaborn as sns

# %%
# !pip show seaborn #Versão
# Out:
# Name: seaborn
# Version: 0.9.0
# Summary: seaborn: statistical data visualization
# Home-page: https://seaborn.pydata.org
# Author: Michael Waskom
# Author-email: mwaskom@nyu.edu
# License: BSD (3-clause)
# Location: /home/lorraine/anaconda3/lib/python3.8/site-packages
# Requires: pandas, matplotlib, numpy, scipy
# Required-by:

# %% [markdown]
# ### Análise 1 - Valor da conta e gorjeta

# %%
gorjetas.columns #Vendo quais colunas nós temos
# Out:
# Index(['valor_da_conta', 'gorjeta', 'sobremesa', 'dia_da_semana',
#        'hora_do_dia', 'total_de_pessoas'],
#       dtype='object')

# %%
# Queremos ver se conforme a conta aumenta a gorjeta tbm??

valor_gorjeta = sns.scatterplot(x='valor_da_conta', y='gorjeta', data=gorjetas)

# %% [markdown]
# Visualmente o valor da gorjeta aumenta conforme aumenta o valor da conta, de forma linear.
#
# Importante percebermos que não temos valores nulos.

# %%
# Quantos registros temos em nossa base?

gorjetas.shape[0]
print('A base de dados contém {} de registros'.format(gorjetas.shape[0]))
# Out:
# A base de dados contém 244 de registros

# %%
# Será que todos os registros estão preenchidos ou temos alguns nulos??
gorjetas.count()
print('Registros não nulos\n{}'.format(gorjetas.count()))
# Out:
# Registros não nulos
# valor_da_conta      244
# gorjeta             244
# sobremesa           244
# dia_da_semana       244
# hora_do_dia         244
# total_de_pessoas    244
# dtype: int64

# %% [markdown]
# ## Criando o campo porcentagem

# %%
# Será que o valor da gorjeta é proporcional ao valor da conta?
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
#
#    total_de_pessoas
# 0                 2

# %%
# Criando um novo campo
gorjetas['porcentagem'] = gorjetas['gorjeta']/gorjetas['valor_da_conta']

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2     0.059447
# 1                 3     0.160542
# 2                 3     0.166587
# 3                 2     0.139780
# 4                 4     0.146808

# %%
# Arredondando o valor da porcentagem
gorjetas.porcentagem = gorjetas.porcentagem.round(2)

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
# Quero visualisar um gráfico do valor da conta pela porcentagem.
porcentagem_conta = sns.scatterplot( x = 'valor_da_conta', y='porcentagem', data = gorjetas )

# %% [markdown]
# Visualmente o valor da conta não é proporcional a gorjeta.
#
# Aumentando o valor da conta as gorjetas são maiores, mas elas não são proporcionais

# %% [markdown]
# ## Relplot e lmplot

# %%
 # Gerando gráficos de linha
    
porcentagem_conta_linha = sns.relplot(x = 'valor_da_conta', y = 'porcentagem', data = gorjetas)

# %%
    
porcentagem_conta_linha = sns.relplot(x = 'valor_da_conta', y = 'porcentagem', kind='line', data = gorjetas)

# %%
# Utilizar o lmplot para visualisar qual a progressão que estamos tendo

sns.lmplot( x='valor_da_conta', y='porcentagem', data = gorjetas )
sns.lmplot( x='valor_da_conta', y='gorjeta', data = gorjetas )

# %% [markdown]
# Visualmente, a distribuição apresenta poucas diferenças

# %% [markdown]
# # Módulo 3 - Analisando de forma visual e descritiva

# %% [markdown]
# ## Análise descritiva

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
# Pedir sobremesa influencia no valor da gorjeta ?

# %% [markdown]
# ### Análise 2 - Sobremesa

# %%
gorjetas[gorjetas.sobremesa == 'Sim']
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 56            38.01     3.00       Sim        Sábado      Jantar
# 58            11.24     1.76       Sim        Sábado      Jantar
# 60            20.29     3.21       Sim        Sábado      Jantar
# 61            13.81     2.00       Sim        Sábado      Jantar
# 62            11.02     1.98       Sim        Sábado      Jantar
# ..              ...      ...       ...           ...         ...
# 234           15.53     3.00       Sim        Sábado      Jantar
# 236           12.60     1.00       Sim        Sábado      Jantar
# 237           32.83     1.17       Sim        Sábado      Jantar
# 240           27.18     2.00       Sim        Sábado      Jantar
# 241           22.67     2.00       Sim        Sábado      Jantar
#
#      total_de_pessoas  porcentagem
# 56                  4         0.08
# 58                  2         0.16
# 60                  2         0.16
# 61                  2         0.14
# ...

# %%
gorjetas[gorjetas.sobremesa == 'Sim'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count       93.000000  93.000000         93.000000    93.000000
# mean        20.756344   3.008710          2.408602     0.163226
# std          9.832154   1.401468          0.810751     0.085060
# min          3.070000   1.000000          1.000000     0.040000
# 25%         13.420000   2.000000          2.000000     0.110000
# 50%         17.920000   3.000000          2.000000     0.150000
# 75%         26.860000   3.680000          3.000000     0.200000
# max         50.810000  10.000000          5.000000     0.710000

# %%
gorjetas[gorjetas.sobremesa == 'Não'].describe()
# Out:
#        valor_da_conta     gorjeta  total_de_pessoas  porcentagem
# count      151.000000  151.000000        151.000000   151.000000
# mean        19.188278    2.991854          2.668874     0.159536
# std          8.255582    1.377190          1.017984     0.039889
# min          7.250000    1.000000          1.000000     0.060000
# 25%         13.325000    2.000000          2.000000     0.140000
# 50%         17.590000    2.740000          2.000000     0.160000
# 75%         22.755000    3.505000          3.000000     0.185000
# max         48.330000    9.000000          6.000000     0.290000

# %% [markdown]
# ## Análise visual

# %%
#gráfico categórico

sns.catplot(x ='sobremesa', y ='gorjeta', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', data=gorjetas)
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', col='sobremesa', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', col='sobremesa', data=gorjetas)
sns.relplot(x='valor_da_conta', y='gorjeta', col='sobremesa', hue='sobremesa', kind='line', data=gorjetas)

# %%
#traçando uma linha

sns.lmplot(x='valor_da_conta', y='gorjeta', col='sobremesa', hue='sobremesa', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', col='sobremesa', hue='sobremesa', data=gorjetas)

# %% [markdown]
# Visualmente existe uma diferença no valor da gorjeta daqueles que pediram sobremesa e não pediram sobremesa

# %% [markdown]
# ## Teste de hipóteses

# %% [markdown]
# ### H<sup>null</sup>
# ** A distribuição da taxa da gorjeta é a mesma nos dois grupos **
#
# ### H<sup>alt</sup>
# ** A distribuição da taxa da gorjeta não é a mesma nos dois grupos **

# %%
from scipy.stats import ranksums

# %%
# Porcentagem de todas as pessoas que pediram gorjeta

sobremesa = gorjetas.query("sobremesa == 'Sim'").porcentagem

# %%
sem_sobremesa = gorjetas.query("sobremesa == 'Não'").porcentagem

# %%
ranksums(sobremesa, sem_sobremesa) #pvalue + apesar dos dois darem gorjetas, matemáticamente a diferença é insignificante
#Portanto continuamos com a hipótise nula
# Out:
# RanksumsResult(statistic=-0.6331073145314825, pvalue=0.5266635660124415)

# %%
r = ranksums(sobremesa, sem_sobremesa)
print('O valor do p-value é {}'.format(r.pvalue))
# Out:
# O valor do p-value é 0.5266635660124415

# %% [markdown]
# ### H<sup>null</sup>
# ** A distribuição da taxa da gorjeta é a mesma nos dois grupos **

# %% [markdown]
# # Módulo 4 - Comparando e explorando os dias da semana

# %% [markdown]
# ## Análise 3 - Dias da semana

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
gorjetas.dia_da_semana.unique() #Quais dias da semana temos em nossa base?
# Out:
# array(['Domingo', 'Sábado', 'Quinta', 'Sexta'], dtype=object)

# %%
#Plotando um gráfico em relação a conta e dias da semana para ver qual dia gastam mais

sns.catplot(x='dia_da_semana', y='valor_da_conta', data=gorjetas)

# %%
#Fazendo todos em um gráfico só

sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', data=gorjetas) #hue -> cada dia de uma cor

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', col='dia_da_semana', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana',col='dia_da_semana', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana',col='dia_da_semana', data=gorjetas)

# %% [markdown]
# ### Análise descritiva

# %%
# Vendo a média dos valores de gorjetas

# %%
media_gorjetas=gorjetas.gorjeta.mean()
print('A média geral das gorjetas é de {}'.format(media_gorjetas))
# Out:
# A média geral das gorjetas é de 2.9982786885245902

# %%
gorjetas.groupby(['dia_da_semana']).mean() #média de cada dia
# Out:
#                valor_da_conta   gorjeta  total_de_pessoas  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132          2.842105     0.166974
# Quinta              17.682742  2.771452          2.451613     0.161129
# Sexta               17.151579  2.734737          2.105263     0.169474
# Sábado              20.441379  2.993103          2.517241     0.153678

# %%
gorjetas.groupby(['dia_da_semana']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
#                valor_da_conta   gorjeta  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132     0.166974
# Quinta              17.682742  2.771452     0.161129
# Sexta               17.151579  2.734737     0.169474
# Sábado              20.441379  2.993103     0.153678

# %%
print('Frequência dos dias')
gorjetas.dia_da_semana.value_counts() #frequencia
# Out:
# Frequência dos dias
# Sábado     87
# Domingo    76
# Quinta     62
# Sexta      19
# Name: dia_da_semana, dtype: int64

# %% [markdown]
# ### Teste de hipóteses
#
# ### H<sup>null</sup>
# ** A distribuição da taxa da gorjeta é a mesma no sábado e no domingo**
#
# ### H<sup>alt</sup>
# ** A distribuição da taxa da gorjeta não é a mesma no sábado e no domingo **

# %%
valor_conta_domingo = gorjetas.query("dia_da_semana == 'Domingo'").valor_da_conta

# %%
valor_conta_sabado = gorjetas.query("dia_da_semana == 'Sábado'").valor_da_conta

# %%
r2 = ranksums(valor_conta_domingo, valor_conta_sabado)

# %% [markdown]
# 0,35 -> A hipótese alternativa só valo se o pvalue > 0.5 então continuamos com a alternativa nula

# %%
print('O valor do pvalue é {}'.format(r2.pvalue))
# Out:
# O valor do pvalue é 0.3576728477868443

# %% [markdown]
# # Módulo 5 - Distribuição de frequência e teste de hipótese

# %% [markdown]
# ## Analise 4 - Hora do dia

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Jantar', 'Almoço'], dtype=object)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta',kind='swarm', data=gorjetas) #Vendo melhor os pontos sobrepostos

# %%
sns.violinplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
sns.boxplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas) #as médias são diferentes
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
#fazendo um histograma

almoço = gorjetas.query('hora_do_dia == "Almoço"').valor_da_conta

# %%
sns.distplot(almoço, kde = False)
# Out:
# <AxesSubplot:xlabel='valor_da_conta'>

# %%
sns.distplot(almoço)
# Out:
# <AxesSubplot:xlabel='valor_da_conta'>

# %%
jantar = gorjetas.query('hora_do_dia == "Jantar"').valor_da_conta

# %%
sns.distplot(jantar)
# Out:
# <AxesSubplot:xlabel='valor_da_conta'>

# %%
sns.distplot(jantar, kde=False)
# Out:
# <AxesSubplot:xlabel='valor_da_conta'>

# %% [markdown]
# ### Teste de hipótese

# %%
gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
#              valor_da_conta   gorjeta  porcentagem
# hora_do_dia
# Almoço            17.168676  2.728088     0.163971
# Jantar            20.797159  3.102670     0.159773

# %% [markdown]
# ### H<sup>null</sup>
# ** A distribuição do valor da conta é igual no jantar e no almoço**
#
# ### H<sup>alt</sup>
# ** A distribuição do valor da aconta não é igual no almoço e no jantar **

# %%
r3 = ranksums(jantar, almoço)

# %%
## Se pvalue < 0.005 podemos aceitar a hipótese alternativa.

print('O valor do pvalue é de {}'.format(r3.pvalue))
# Out:
# O valor do pvalue é de 0.0011791039723641672

# %%
porcentagem_almoco = gorjetas.query('hora_do_dia == "Almoço"').porcentagem

# %%
porcentagem_jantar = gorjetas.query('hora_do_dia == "Jantar"').porcentagem

# %%
r4 = ranksums(porcentagem_almoco,porcentagem_jantar)
#O valor não é menor que 0,005 então temos grupos diferentes mantem a hipótese nula

# %%
print('O valor do pvalue é de {}'.format(r4.pvalue))
# Out:
# O valor do pvalue é de 0.2602493995587126
